# %% [markdown]
# # Precinct Matching Framework

# %%
import pandas as pd
import geopandas as gpd
from pprint import pprint

# %% [markdown]
# ### Import the datasets

# %%
county_id = 'Albany County'

county_results_filename = 'election_results_county_id={}.csv'.format(county_id)
county_results_df = pd.read_csv(county_results_filename)
county_shapefile_filename = 'shapefile_county_id={}'.format(county_id)
county_shapefile_gdf = gpd.read_file(county_shapefile_filename)

# correct for the truncation caused by 10 character column name limit in shapefiles
county_shapefile_gdf.rename(columns={'original_p':'original_precinct_name'}, inplace=True)

# %% [markdown]
# The next cell aliases `county_results_df` as `df` and `county_shapefile_gdf` as `gdf` here because typing fewer characters allows for faster data exploration.

# %%
df = county_results_df.copy()
gdf = county_shapefile_gdf.copy()

# %%
df.head()
# Out:
#           county            precinct  HOR_DEM  HOR_REP  HOR_CON  HOR_GRE  \
# 0  Albany County  0001 ALBANY W1 ED1       40        7        0        0
# 1  Albany County  0002 ALBANY W1 ED2      182       20        0        0
# 2  Albany County  0003 ALBANY W1 ED3      241       41        0        0
# 3  Albany County  0004 ALBANY W1 ED4      245       18        0        0
# 4  Albany County  0005 ALBANY W1 ED5        4        0        0        0
#
#    HOR_WOR  HOR_IND  HOR_WEP  HOR_REF  ...  Gov_CON  Gov_GRE  Gov_WOR  \
# 0        5        0        1        0  ...        1        3        3
# 1       21        0        6        3  ...       11       15       11
# 2       11        0        1        4  ...       11        4       10
# 3       18        0        5        3  ...        5        4       12
# 4        0        0        0        0  ...        0        1        0
#
#    Gov_IND  Gov_WEP  Gov_REF  Gov_SAM  Gov_LBT      county_id  \
# 0        0        0        0        2        1  Albany County
# 1        1        1        2        9        3  Albany County
# 2        1        3        0        5        5  Albany County
# 3        4        1        3        7        4  Albany County
# 4        0        0        0        0        0  Albany County
#
#    original_precinct_name
# 0      0001 ALBANY W1 ED1
# 1      0002 ALBANY W1 ED2
# 2      0003 ALBANY W1 ED3
# 3      0004 ALBANY W1 ED4
# 4      0005 ALBANY W1 ED5
#
# [5 rows x 29 columns]

# %%
gdf.head()
# Out:
#   STATEFP COUNTYFP   VTDST NAMELSAD VTDI LSAD CHNG_TYPE ORIG_NAME ORIG_CODE  \
# 0      36      001  000001   000001    A   00      None      None      None
# 1      36      001  000002   000002    A   00      None      None      None
# 2      36      001  000003   000003    A   00      None      None      None
# 3      36      001  000011   000011    A   00      None      None      None
# 4      36      001  000013   000013    A   00      None      None      None
#
#   RELATE    NAME VINTAGE FUNCSTAT JUSTIFY  MTFCC      county_id  \
# 0   None  000001      90        N    None  G5240  Albany County
# 1   None  000002      90        N    None  G5240  Albany County
# 2   None  000003      90        N    None  G5240  Albany County
# 3   None  000011      90        N    None  G5240  Albany County
# 4   None  000013      90        N    None  G5240  Albany County
#
#   original_precinct_name                                           geometry
# 0                 000001  POLYGON Z ((-73.81005 42.63703 0.00000, -73.81...
# 1                 000002  POLYGON Z ((-73.79377 42.63951 0.00000, -73.79...
# 2                 000003  POLYGON Z ((-73.79031 42.63767 0.00000, -73.79...
# 3                 000011  POLYGON Z ((-73.76981 42.64066 0.00000, -73.76...
# 4                 000013  POLYGON Z ((-73.76204 42.63530 0.00000, -73.76...

# %% [markdown]
# ### Check Preconditions
# These should all pass - they're here to ensure that everything in `setup.ipynb` worked correctly

# %%
# TODO: Pass the precondition described above which takes the form of an assert statement in this cell.
assert 'county_id' in df.columns and 'county_id' in gdf.columns
assert 'original_precinct_name' in df.columns and 'original_precinct_name' in gdf.columns

# %% [markdown]
# ### General Modifications
# Its normally benificial to apply some modifications uniformly to all precincts. For example, its good practice to make everything lower case. This modification is made in `edit_precinct_name` - read its specification to learn more about how to use it to make more modifications. Consider removing substrings that appear in every precinct name like `voting district`. Be careful of removing words that will result in duplicate precinct names. For example, if there are two `Newtown Voting District` precincts in the shapefile, and the election results have `Newtown Boro` and `Newtown Township`, its okay to remove `Voting District`, but you probably don't want to remove `Boro` or `Township`. Of course, this will differ from County to County - so be vigilant!

# %%
dataset_name_df = 'df'
dataset_name_gdf = 'gdf'

def edit_precinct_name(prec_name, 
    remove_lst=[], 
    target_to_replacement={},
    stopping_words=[],
    prec_dict={}):
    '''
    Returns a lower case precinct name (string) with certian modifications depending other arguments. 
    
    Modifications are performed in order of the parameters they depend on. By convention, case is 
    ignored by making prec_name lower case. Accordingly, one should pass arguements with lower case
    elements. That is, keys of the dictionaries and elements of lists should be lower case strings.

	Parameters:
		prec_name (str): precinct name
		remove_lst ((str) list): if a string in this list is a substring in prec_name it will be removed. 
            All elements should be lower case.
        target_to_replacement ({str:str} dictionary): keys (targets) will be replaced with their 
            corresponding value (replacements) in prec_name. All keys should be lower case.
        stopping_words ({str} list): If any substring of prec_name contains a element of stopping_words
             that is adjacent to a space character it will be removed. All elements should be lower case.
        prec_dict ({str:str} dictionary): After all the modifications above, if the edited prec_name
            string is in the set of keys for prec_dict, then it will be replaced with that key's value.  
            All keys should be lower case.

	Returns:
		prec_name (str): prec_name arguement returned with the 
    '''
    prec_name = str(prec_name).lower()
    for word in remove_lst:
        prec_name = prec_name.replace(word, '')
    for target, replacement in target_to_replacement.items():
        prec_name = prec_name.replace(target, replacement)
    words = prec_name.split()
    words = [word.lstrip('0') for word in words if word not in stopping_words]
    prec_name = " ".join(words)
    return prec_dict[prec_name] if prec_name in prec_dict.keys() else prec_name

df_to_gdf = {
}

gdf_to_df = {
}

# Tune the matching by adding optional arguements to edit
df['edited_precinct_name'] = df['original_precinct_name'].apply(lambda name: edit_precinct_name(name,prec_dict=df_to_gdf))
gdf['edited_precinct_name'] = gdf['original_precinct_name'].apply(lambda name: edit_precinct_name(name,prec_dict=gdf_to_df))

######## Manual Corrections ###########
# Make precinct specific corrections here like splitting one precinct into two because of new congressional districts
# e.g gdf.loc[gdf['VTDST']=='000290','edited_precinct_name'] = 'howard township'

# make the 'original_precinct_name, edited_precinct_name' for use in the loop below
df['original_precinct_name, edited_precinct_name'] = df[['original_precinct_name','edited_precinct_name']].apply(tuple, axis=1)
gdf['original_precinct_name, edited_precinct_name'] = gdf[['original_precinct_name','edited_precinct_name']].apply(tuple, axis=1)

######## Matching Framework ###########
unmatched_precinct_lst_gdf = []
unmatched_precinct_lst_df = []

precinct_list_df = sorted(list(df[df['county_id'] == county_id]['original_precinct_name, edited_precinct_name'].unique()), key=lambda x: x[1])
precinct_list_gdf = sorted(list(gdf[gdf['county_id'] == county_id]['original_precinct_name, edited_precinct_name'].unique()), key=lambda x: x[1])

precinct_set_df = {x[1] for x in precinct_list_df if x[1] not in unmatched_precinct_lst_df}
precinct_set_gdf = {x[1] for x in precinct_list_gdf if x[1] not in unmatched_precinct_lst_gdf}

unmatched_precincts_df = sorted(list(precinct_set_df - precinct_set_gdf))
unmatched_precincts_gdf = sorted(list(precinct_set_gdf - precinct_set_df))
n_unmatched = len(unmatched_precincts_df) + len(unmatched_precincts_gdf)
if n_unmatched > 0:
        print("county_id: '{}' | {} precincts in {} | {} precincts in {}:\n".format(county_id, len(precinct_list_df), dataset_name_df, len(precinct_list_gdf), dataset_name_gdf))
        n_precincts_total = len(precinct_list_df) + len(precinct_list_gdf)
        print(n_unmatched, " precincts are unmatched out of ", n_precincts_total)
        df_unmatched = df[(df['edited_precinct_name'].isin(unmatched_precincts_df)) & (df.county_id == county_id)]
        gdf_unmatched = gdf[(gdf['edited_precinct_name'].isin(unmatched_precincts_gdf)) & (gdf.county_id == county_id)]
        if n_unmatched > 100:
            print("\nLook for parterns and use change the parameters to edit_precinct_name accordingly.\n")
            for index, (original_precinct_name_df, edited_precinct_name_df) in enumerate(precinct_list_df):
                original_precinct_name_gdf, edited_precinct_name_gdf = precinct_list_gdf[index]
                if edited_precinct_name_df in unmatched_precincts_df and edited_precinct_name_gdf in unmatched_precincts_gdf:
                    print("{} <-- {} ({})".format(edited_precinct_name_df, original_precinct_name_df, dataset_name_df))
                    print("{} <-- {} ({})\n".format(edited_precinct_name_gdf, original_precinct_name_gdf, dataset_name_gdf))
        else:
            print("unmatched_precincts_df ({}) - len = {}| '{}':".format(dataset_name_df, len(unmatched_precincts_df), county_id), unmatched_precincts_df)
            print("\nunmatched_precincts_gdf ({}) - len = {}| '{}':".format(dataset_name_gdf, len(unmatched_precincts_gdf), county_id), unmatched_precincts_gdf)
            precinct_modification_dictionary_df_to_gdf = {unmatched_precincts_df[i]: unmatched_precincts_gdf[i] if i < len(unmatched_precincts_gdf) else '' for i in range(len(unmatched_precincts_df))}
            precinct_modification_dicitonary_gdf_to_df = {unmatched_precincts_gdf[i]: unmatched_precincts_df[i] if i < len(unmatched_precincts_df) else '' for i in range(len(unmatched_precincts_gdf))}
            print("{}  to {} precinct modification dictionary: ".format(dataset_name_df, dataset_name_gdf))
            print("'{}':".format(county_id))
            pprint(precinct_modification_dictionary_df_to_gdf)
            print("{}  to {} precinct modification dictionary: ".format(dataset_name_gdf, dataset_name_df))
            print("'{}':".format(county_id))
            pprint(precinct_modification_dicitonary_gdf_to_df)
            for index, (original_precinct_name_df, edited_precinct_name_df) in enumerate(precinct_list_df):
                original_precinct_name_gdf, edited_precinct_name_gdf = precinct_list_gdf[index]
                if edited_precinct_name_df in unmatched_precincts_df or edited_precinct_name_gdf in unmatched_precincts_gdf:
                    print("{} <-- {} ({})".format(edited_precinct_name_df, original_precinct_name_df, dataset_name_df))
                    print("{} <-- {} ({})\n".format(edited_precinct_name_gdf, original_precinct_name_gdf, dataset_name_gdf))
            else:
                print("Add unmatched precincts to the unmatched precinct.")
else:
    print("All Done! (make sure you have one to one matches)")
# Out:
# county_id: 'Albany County' | 329 precincts in df | 313 precincts in gdf:
#
# 642  precincts are unmatched out of  642
#
# Look for parterns and use change the parameters to edit_precinct_name accordingly.
#
# 1 albany w1 ed1 <-- 0001 ALBANY W1 ED1 (df)
# 1 <-- 000001 (gdf)
#
# 10 albany w1 ed10 <-- 0010 ALBANY W1 ED10 (df)
# 10 <-- 000010 (gdf)
#
# 100 albany w12 ed4 <-- 0100 ALBANY W12 ED4 (df)
# 100 <-- 000100 (gdf)
#
# 101 albany w12 ed5 <-- 0101 ALBANY W12 ED5 (df)
# 101 <-- 000101 (gdf)
#
# 102 albany w12 ed6 <-- 0102 ALBANY W12 ED6 (df)
# 102 <-- 000102 (gdf)
#
# 103 albany w12 ed7 <-- 0103 ALBANY W12 ED7 (df)
# 103 <-- 000103 (gdf)
#
# 104 albany w12 ed8 <-- 0104 ALBANY W12 ED8 (df)
# 104 <-- 000104 (gdf)
#
# 105 albany w12 ed91 <-- 0105 ALBANY W12 ED91 (df)
# 106 <-- 000106 (gdf)
#
# 106 albany w13 ed1 <-- 0106 ALBANY W13 ED1 (df)
# 11 <-- 000011 (gdf)
#
# 107 albany w13 ed2 <-- 0107 ALBANY W13 ED2 (df)
# 110 <-- 000110 (gdf)
#
# 108 albany w13 ed3 <-- 0108 ALBANY W13 ED3 (df)
# 111 <-- 000111 (gdf)
#
# 109 albany w13 ed4 <-- 0109 ALBANY W13 ED4 (df)
# 113 <-- 000113 (gdf)
#
# 11 albany w2 ed1 <-- 0011 ALBANY W2 ED1 (df)
# 115 <-- 000115 (gdf)
#
# 110 albany w13 ed5 <-- 0110 ALBANY W13 ED5 (df)
# 116 <-- 000116 (gdf)
#
# 111 albany w13 ed6 <-- 0111 ALBANY W13 ED6 (df)
# 12 <-- 000012 (gdf)
#
# 112 albany w13 ed7 <-- 0112 ALBANY W13 ED7 (df)
# 120 <-- 000120 (gdf)
#
# 113 albany w14 ed1 <-- 0113 ALBANY W14 ED1 (df)
# 121 <-- 000121 (gdf)
#
# 114 albany w14 ed2 <-- 0114 ALBANY W14 ED2 (df)
# 124 <-- 000124 (gdf)
#
# 115 albany w14 ed3 <-- 0115 ALBANY W14 ED3 (df)
# 125 <-- 000125 (gdf)
#
# 116 albany w14 ed4 <-- 0116 ALBANY W14 ED4 (df)
# 126 <-- 000126 (gdf)
#
# 117 albany w14 ed5 <-- 0117 ALBANY W14 ED5 (df)
# 128 <-- 000128 (gdf)
#
# 118 albany w14 ed6 <-- 0118 ALBANY W14 ED6 (df)
# 13 <-- 000013 (gdf)
#
# 119 albany w14 ed7 <-- 0119 ALBANY W14 ED7 (df)
# 130 <-- 000130 (gdf)
#
# 12 albany w2 ed2 <-- 0012 ALBANY W2 ED2 (df)
# 131 <-- 000131 (gdf)
#
# 120 albany w14 ed8 <-- 0120 ALBANY W14 ED8 (df)
# 133 <-- 000133 (gdf)
#
# 121 albany w14 ed9 <-- 0121 ALBANY W14 ED9 (df)
# 134 <-- 000134 (gdf)
#
# 122 albany w15 ed1 <-- 0122 ALBANY W15 ED1 (df)
# 137 <-- 000137 (gdf)
#
# 123 albany w15 ed2 <-- 0123 ALBANY W15 ED2 (df)
# 138 <-- 000138 (gdf)
#
# 124 albany w15 ed3 <-- 0124 ALBANY W15 ED3 (df)
# 139 <-- 000139 (gdf)
#
# 125 albany w15 ed4 <-- 0125 ALBANY W15 ED4 (df)
# 14 <-- 000014 (gdf)
#
# 126 albany w15 ed5 <-- 0126 ALBANY W15 ED5 (df)
# 142 <-- 000142 (gdf)
#
# 127 albany w15 ed6 <-- 0127 ALBANY W15 ED6 (df)
# 144 <-- 000144 (gdf)
#
# 128 albany w15 ed7 <-- 0128 ALBANY W15 ED7 (df)
# 147 <-- 000147 (gdf)
#
# 129 cohoes w1 ed1 <-- 0129 COHOES W1 ED1 (df)
# 149 <-- 000149 (gdf)
#
# 13 albany w2 ed3 <-- 0013 ALBANY W2 ED3 (df)
# 15 <-- 000015 (gdf)
#
# 130 cohoes w1 ed2 <-- 0130 COHOES W1 ED2 (df)
# 151 <-- 000151 (gdf)
#
# 131 cohoes w1 ed3 <-- 0131 COHOES W1 ED3 (df)
# 153 <-- 000153 (gdf)
#
# 132 cohoes w2 ed1 <-- 0132 COHOES W2 ED1 (df)
# 155 <-- 000155 (gdf)
#
# 133 cohoes w2 ed2 <-- 0133 COHOES W2 ED2 (df)
# 156 <-- 000156 (gdf)
#
# 134 cohoes w2 ed3 <-- 0134 COHOES W2 ED3 (df)
# 157 <-- 000157 (gdf)
#
# 135 cohoes w2 ed4 <-- 0135 COHOES W2 ED4 (df)
# 158 <-- 000158 (gdf)
#
# 136 cohoes w2 ed5 <-- 0136 COHOES W2 ED5 (df)
# 16 <-- 000016 (gdf)
#
# 137 cohoes w2 ed6 <-- 0137 COHOES W2 ED6 (df)
# 161 <-- 000161 (gdf)
#
# 138 cohoes w3 ed1 <-- 0138 COHOES W3 ED1 (df)
# 164 <-- 000164 (gdf)
#
# 139 cohoes w3 ed2 <-- 0139 COHOES W3 ED2 (df)
# 17 <-- 000017 (gdf)
#
# 14 albany w2 ed4 <-- 0014 ALBANY W2 ED4 (df)
# 170 <-- 000170 (gdf)
#
# 140 cohoes w3 ed3 <-- 0140 COHOES W3 ED3 (df)
# 171 <-- 000171 (gdf)
#
# 141 cohoes w3 ed4 <-- 0141 COHOES W3 ED4 (df)
# 173 <-- 000173 (gdf)
#
# 142 cohoes w4 ed1 <-- 0142 COHOES W4 ED1 (df)
# 178 <-- 000178 (gdf)
#
# 143 cohoes w4 ed2 <-- 0143 COHOES W4 ED2 (df)
# 179 <-- 000179 (gdf)
#
# 144 cohoes w4 ed3 <-- 0144 COHOES W4 ED3 (df)
# 18 <-- 000018 (gdf)
#
# 145 cohoes w4 ed4 <-- 0145 COHOES W4 ED4 (df)
# 181 <-- 000181 (gdf)
#
# 146 cohoes w5 ed1 <-- 0146 COHOES W5 ED1 (df)
# 188 <-- 000188 (gdf)
#
# 147 cohoes w5 ed2 <-- 0147 COHOES W5 ED2 (df)
# 189 <-- 000189 (gdf)
#
# 148 cohoes w5 ed3 <-- 0148 COHOES W5 ED3 (df)
# 19 <-- 000019 (gdf)
#
# 149 cohoes w5 ed4 <-- 0149 COHOES W5 ED4 (df)
# 190 <-- 000190 (gdf)
#
# 15 albany w2 ed5 <-- 0015 ALBANY W2 ED5 (df)
# 192 <-- 000192 (gdf)
#
# 150 cohoes w5 ed5 <-- 0150 COHOES W5 ED5 (df)
# 195 <-- 000195 (gdf)
#
# 151 cohoes w6 ed1 <-- 0151 COHOES W6 ED1 (df)
# 196 <-- 000196 (gdf)
#
# 152 cohoes w6 ed2 <-- 0152 COHOES W6 ED2 (df)
# 199 <-- 000199 (gdf)
#
# 153 cohoes w6 ed3 <-- 0153 COHOES W6 ED3 (df)
# 2 <-- 000002 (gdf)
#
# 154 cohoes w6 ed4 <-- 0154 COHOES W6 ED4 (df)
# 20 <-- 000020 (gdf)
#
# 155 watervliet w1 ed1 <-- 0155 WATERVLIET W1 ED1 (df)
# 202 <-- 000202 (gdf)
#
# 155 watervliet ward 1 ed 1 <-- 0155 WATERVLIET WARD 1 ED 1 (df)
# 203 <-- 000203 (gdf)
#
# 156 watervliet w1 ed2 <-- 0156 WATERVLIET W1 ED2 (df)
# 204 <-- 000204 (gdf)
#
# 156 watervliet ward 1 ed 2 <-- 0156 WATERVLIET WARD 1 ED 2 (df)
# 205 <-- 000205 (gdf)
#
# 157 watervliet w1 ed3 <-- 0157 WATERVLIET W1 ED3 (df)
# 208 <-- 000208 (gdf)
#
# 157 watervliet ward 1 ed 3 <-- 0157 WATERVLIET WARD 1 ED 3 (df)
# 209 <-- 000209 (gdf)
#
# 158 watervliet w2 ed1 <-- 0158 WATERVLIET W2 ED1 (df)
# 21 <-- 000021 (gdf)
#
# 158 watervliet ward 2 ed 1 <-- 0158 WATERVLIET WARD 2 ED 1 (df)
# 211 <-- 000211 (gdf)
#
# 159 watervliet w2 ed2 <-- 0159 WATERVLIET W2 ED2 (df)
# 212 <-- 000212 (gdf)
#
# 159 watervliet w2 ed3 <-- 0159 WATERVLIET W2 ED3 (df)
# 213 <-- 000213 (gdf)
#
# 159 watervliet ward 2 ed 2 <-- 0159 WATERVLIET WARD 2 ED 2 (df)
# 216 <-- 000216 (gdf)
#
# 16 albany w2 ed6 <-- 0016 ALBANY W2 ED6 (df)
# 219 <-- 000219 (gdf)
#
# 160 watervliet w3 ed1 <-- 0160 WATERVLIET W3 ED1 (df)
# 22 <-- 000022 (gdf)
#
# 160 watervliet ward 2 ed 3 <-- 0160 WATERVLIET WARD 2 ED 3 (df)
# 220 <-- 000220 (gdf)
#
# 161 watervliet w3 ed2 <-- 0161 WATERVLIET W3 ED2 (df)
# 221 <-- 000221 (gdf)
#
# 161 watervliet ward 3 ed 1 <-- 0161 WATERVLIET WARD 3 ED 1 (df)
# 224 <-- 000224 (gdf)
#
# 162 watervliet w3 ed3 <-- 0162 WATERVLIET W3 ED3 (df)
# 227 <-- 000227 (gdf)
#
# 162 watervliet ward 3 ed 2 <-- 0162 WATERVLIET WARD 3 ED 2 (df)
# 228 <-- 000228 (gdf)
#
# 163 watervliet w4 ed1 <-- 0163 WATERVLIET W4 ED1 (df)
# 23 <-- 000023 (gdf)
#
# 163 watervliet ward 3 ed 3 <-- 0163 WATERVLIET WARD 3 ED 3 (df)
# 231 <-- 000231 (gdf)
#
# 164 watervliet w4 ed2 <-- 0164 WATERVLIET W4 ED2 (df)
# 232 <-- 000232 (gdf)
#
# 164 watervliet ward 4 ed 1 <-- 0164 WATERVLIET WARD 4 ED 1 (df)
# 233 <-- 000233 (gdf)
#
# 165 watervliet w4 ed3 <-- 0165 WATERVLIET W4 ED3 (df)
# 236 <-- 000236 (gdf)
#
# 165 watervliet ward 4 ed 2 <-- 0165 WATERVLIET WARD 4 ED 2 (df)
# 237 <-- 000237 (gdf)
#
# 166 watervliet w4 ed4 <-- 0166 WATERVLIET W4 ED4 (df)
# 238 <-- 000238 (gdf)
#
# 166 watervliet ward 4 ed 3 <-- 0166 WATERVLIET WARD 4 ED 3 (df)
# 24 <-- 000024 (gdf)
#
# 167 watervliet ward 4 ed 4 <-- 0167 WATERVLIET WARD 4 ED 4 (df)
# 241 <-- 000241 (gdf)
#
# 168 berne ed 1 <-- 0168 BERNE ED 1 (df)
# 242 <-- 000242 (gdf)
#
# 169 berne ed 2 <-- 0169 BERNE ED 2 (df)
# 246 <-- 000246 (gdf)
#
# 17 albany w2 ed7 <-- 0017 ALBANY W2 ED7 (df)
# 247 <-- 000247 (gdf)
#
# 170 berne ed 3 <-- 0170 BERNE ED 3 (df)
# 248 <-- 000248 (gdf)
#
# 171 bethlehem ed 1 <-- 0171 BETHLEHEM ED 1 (df)
# 25 <-- 000025 (gdf)
#
# 172 bethlehem ed 2 <-- 0172 BETHLEHEM ED 2 (df)
# 252 <-- 000252 (gdf)
#
# 173 bethlehem ed 3 <-- 0173 BETHLEHEM ED 3 (df)
# 253 <-- 000253 (gdf)
#
# 174 bethlehem ed 4 <-- 0174 BETHLEHEM ED 4 (df)
# 254 <-- 000254 (gdf)
#
# 175 bethlehem ed 5 <-- 0175 BETHLEHEM ED 5 (df)
# 258 <-- 000258 (gdf)
#
# 176 bethlehem ed 6 <-- 0176 BETHLEHEM ED 6 (df)
# 259 <-- 000259 (gdf)
#
# 177 bethlehem ed 7 <-- 0177 BETHLEHEM ED 7 (df)
# 26 <-- 000026 (gdf)
#
# 178 bethlehem ed 8 <-- 0178 BETHLEHEM ED 8 (df)
# 261 <-- 000261 (gdf)
#
# 179 bethlehem ed 9 <-- 0179 BETHLEHEM ED 9 (df)
# 264 <-- 000264 (gdf)
#
# 18 albany w2 ed8 <-- 0018 ALBANY W2 ED8 (df)
# 265 <-- 000265 (gdf)
#
# 180 bethlehem ed 10 <-- 0180 BETHLEHEM ED 10 (df)
# 266 <-- 000266 (gdf)
#
# 181 bethlehem ed 11 <-- 0181 BETHLEHEM ED 11 (df)
# 27 <-- 000027 (gdf)
#
# 182 bethlehem ed 12 <-- 0182 BETHLEHEM ED 12 (df)
# 271 <-- 000271 (gdf)
#
# 183 bethlehem ed 13 <-- 0183 BETHLEHEM ED 13 (df)
# 274 <-- 000274 (gdf)
#
# 184 bethlehem ed 14 <-- 0184 BETHLEHEM ED 14 (df)
# 275 <-- 000275 (gdf)
#
# 185 bethlehem ed 15 <-- 0185 BETHLEHEM ED 15 (df)
# 278 <-- 000278 (gdf)
#
# 186 bethlehem ed 16 <-- 0186 BETHLEHEM ED 16 (df)
# 279 <-- 000279 (gdf)
#
# 187 bethlehem ed 17 <-- 0187 BETHLEHEM ED 17 (df)
# 28 <-- 000028 (gdf)
#
# 188 bethlehem ed 18 <-- 0188 BETHLEHEM ED 18 (df)
# 281 <-- 000281 (gdf)
#
# 189 bethlehem ed 19 <-- 0189 BETHLEHEM ED 19 (df)
# 284 <-- 000284 (gdf)
#
# 19 albany w2 ed9 <-- 0019 ALBANY W2 ED9 (df)
# 288 <-- 000288 (gdf)
#
# 190 bethlehem ed 20 <-- 0190 BETHLEHEM ED 20 (df)
# 289 <-- 000289 (gdf)
#
# 191 bethlehem ed 21 <-- 0191 BETHLEHEM ED 21 (df)
# 29 <-- 000029 (gdf)
#
# 192 bethlehem ed 22 <-- 0192 BETHLEHEM ED 22 (df)
# 291 <-- 000291 (gdf)
#
# 193 bethlehem ed 23 <-- 0193 BETHLEHEM ED 23 (df)
# 293 <-- 000293 (gdf)
#
# 194 bethlehem ed 24 <-- 0194 BETHLEHEM ED 24 (df)
# 294 <-- 000294 (gdf)
#
# 195 bethlehem ed 25 <-- 0195 BETHLEHEM ED 25 (df)
# 298 <-- 000298 (gdf)
#
# 196 bethlehem ed 26 <-- 0196 BETHLEHEM ED 26 (df)
# 3 <-- 000003 (gdf)
#
# 197 bethlehem ed 27 <-- 0197 BETHLEHEM ED 27 (df)
# 30 <-- 000030 (gdf)
#
# 198 bethlehem ed 28 <-- 0198 BETHLEHEM ED 28 (df)
# 302 <-- 000302 (gdf)
#
# 199 bethlehem ed 29 <-- 0199 BETHLEHEM ED 29 (df)
# 303 <-- 000303 (gdf)
#
# 2 albany w1 ed2 <-- 0002 ALBANY W1 ED2 (df)
# 305 <-- 000305 (gdf)
#
# 200 bethlehem ed 30 <-- 0200 BETHLEHEM ED 30 (df)
# 306 <-- 000306 (gdf)
#
# 201 bethlehem ed 31 <-- 0201 BETHLEHEM ED 31 (df)
# 31 <-- 000031 (gdf)
#
# 202 coeymans ed 1 <-- 0202 COEYMANS ED 1 (df)
# 310 <-- 000310 (gdf)
#
# 203 coeymans ed 2 <-- 0203 COEYMANS ED 2 (df)
# 311 <-- 000311 (gdf)
#
# 204 coeymans ed 3 <-- 0204 COEYMANS ED 3 (df)
# 314 <-- 000314 (gdf)
#
# 205 coeymans ed 4 <-- 0205 COEYMANS ED 4 (df)
# 317 <-- 000317 (gdf)
#
# 206 coeymans ed 5 <-- 0206 COEYMANS ED 5 (df)
# 32 <-- 000032 (gdf)
#
# 207 coeymans ed 6 <-- 0207 COEYMANS ED 6 (df)
# 33 <-- 000033 (gdf)
#
# 208 colonie ed 1 <-- 0208 COLONIE ED 1 (df)
# 34 <-- 000034 (gdf)
#
# 209 colonie ed 2 <-- 0209 COLONIE ED 2 (df)
# 35 <-- 000035 (gdf)
#
# 21 albany w3 ed1 <-- 0021 ALBANY W3 ED1 (df)
# 36 <-- 000036 (gdf)
#
# 210 colonie ed 3 <-- 0210 COLONIE ED 3 (df)
# 37 <-- 000037 (gdf)
#
# 211 colonie ed 4 <-- 0211 COLONIE ED 4 (df)
# 38 <-- 000038 (gdf)
#
# 212 colonie ed 5 <-- 0212 COLONIE ED 5 (df)
# 39 <-- 000039 (gdf)
#
# 213 colonie ed 6 <-- 0213 COLONIE ED 6 (df)
# 4 <-- 000004 (gdf)
#
# 214 colonie ed 7 <-- 0214 COLONIE ED 7 (df)
# 40 <-- 000040 (gdf)
#
# 215 colonie ed 8 <-- 0215 COLONIE ED 8 (df)
# 41 <-- 000041 (gdf)
#
# 216 colonie ed 9 <-- 0216 COLONIE ED 9 (df)
# 42 <-- 000042 (gdf)
#
# 217 colonie ed 10 <-- 0217 COLONIE ED 10 (df)
# 43 <-- 000043 (gdf)
#
# 218 colonie ed 11 <-- 0218 COLONIE ED 11 (df)
# 44 <-- 000044 (gdf)
#
# 219 colonie ed 12 <-- 0219 COLONIE ED 12 (df)
# 45 <-- 000045 (gdf)
#
# 22 albany w3 ed2 <-- 0022 ALBANY W3 ED2 (df)
# 46 <-- 000046 (gdf)
#
# 220 colonie ed 13 <-- 0220 COLONIE ED 13 (df)
# 47 <-- 000047 (gdf)
#
# 221 colonie ed 14 <-- 0221 COLONIE ED 14 (df)
# 48 <-- 000048 (gdf)
#
# 222 colonie ed 15 <-- 0222 COLONIE ED 15 (df)
# 49 <-- 000049 (gdf)
#
# 223 colonie ed 16 <-- 0223 COLONIE ED 16 (df)
# 5 <-- 000005 (gdf)
#
# 224 colonie ed 17 <-- 0224 COLONIE ED 17 (df)
# 50 <-- 000050 (gdf)
#
# 225 colonie ed 18 <-- 0225 COLONIE ED 18 (df)
# 51 <-- 000051 (gdf)
#
# 226 colonie ed 19 <-- 0226 COLONIE ED 19 (df)
# 52 <-- 000052 (gdf)
#
# 227 colonie ed 20 <-- 0227 COLONIE ED 20 (df)
# 53 <-- 000053 (gdf)
#
# 228 colonie ed 21 <-- 0228 COLONIE ED 21 (df)
# 54 <-- 000054 (gdf)
#
# 229 colonie ed 22 <-- 0229 COLONIE ED 22 (df)
# 55 <-- 000055 (gdf)
#
# 23 albany w3 ed3 <-- 0023 ALBANY W3 ED3 (df)
# 56 <-- 000056 (gdf)
#
# 230 colonie ed 23 <-- 0230 COLONIE ED 23 (df)
# 57 <-- 000057 (gdf)
#
# 231 colonie ed 24 <-- 0231 COLONIE ED 24 (df)
# 58 <-- 000058 (gdf)
#
# 232 colonie ed 25 <-- 0232 COLONIE ED 25 (df)
# 59 <-- 000059 (gdf)
#
# 233 colonie ed 26 <-- 0233 COLONIE ED 26 (df)
# 6 <-- 000006 (gdf)
#
# 234 colonie ed 27 <-- 0234 COLONIE ED 27 (df)
# 60 <-- 000060 (gdf)
#
# 235 colonie ed 28 <-- 0235 COLONIE ED 28 (df)
# 61 <-- 000061 (gdf)
#
# 236 colonie ed 29 <-- 0236 COLONIE ED 29 (df)
# 62 <-- 000062 (gdf)
#
# 237 colonie ed 30 <-- 0237 COLONIE ED 30 (df)
# 63 <-- 000063 (gdf)
#
# 238 colonie ed 31 <-- 0238 COLONIE ED 31 (df)
# 64 <-- 000064 (gdf)
#
# 239 colonie ed 32 <-- 0239 COLONIE ED 32 (df)
# 65 <-- 000065 (gdf)
#
# 24 albany w3 ed4 <-- 0024 ALBANY W3 ED4 (df)
# 66 <-- 000066 (gdf)
#
# 240 colonie ed 33 <-- 0240 COLONIE ED 33 (df)
# 67 <-- 000067 (gdf)
#
# 241 colonie ed 34 <-- 0241 COLONIE ED 34 (df)
# 68 <-- 000068 (gdf)
#
# 242 colonie ed 35 <-- 0242 COLONIE ED 35 (df)
# 69 <-- 000069 (gdf)
#
# 243 colonie ed 36 <-- 0243 COLONIE ED 36 (df)
# 7 <-- 000007 (gdf)
#
# 244 colonie ed 37 <-- 0244 COLONIE ED 37 (df)
# 70 <-- 000070 (gdf)
#
# 245 colonie ed 38 <-- 0245 COLONIE ED 38 (df)
# 71 <-- 000071 (gdf)
#
# 246 colonie ed 39 <-- 0246 COLONIE ED 39 (df)
# 72 <-- 000072 (gdf)
#
# 247 colonie ed 40 <-- 0247 COLONIE ED 40 (df)
# 73 <-- 000073 (gdf)
#
# 248 colonie ed 41 <-- 0248 COLONIE ED 41 (df)
# 74 <-- 000074 (gdf)
#
# 249 colonie ed 42 <-- 0249 COLONIE ED 42 (df)
# 75 <-- 000075 (gdf)
#
# 25 albany w3 ed5 <-- 0025 ALBANY W3 ED5 (df)
# 76 <-- 000076 (gdf)
#
# 250 colonie ed 43 <-- 0250 COLONIE ED 43 (df)
# 77 <-- 000077 (gdf)
#
# 251 colonie ed 44 <-- 0251 COLONIE ED 44 (df)
# 78 <-- 000078 (gdf)
#
# 252 colonie ed 45 <-- 0252 COLONIE ED 45 (df)
# 79 <-- 000079 (gdf)
#
# 253 colonie ed 46 <-- 0253 COLONIE ED 46 (df)
# 8 <-- 000008 (gdf)
#
# 254 colonie ed 47 <-- 0254 COLONIE ED 47 (df)
# 80 <-- 000080 (gdf)
#
# 255 colonie ed 48 <-- 0255 COLONIE ED 48 (df)
# 81 <-- 000081 (gdf)
#
# 256 colonie ed 49 <-- 0256 COLONIE ED 49 (df)
# 82 <-- 000082 (gdf)
#
# 257 colonie ed 50 <-- 0257 COLONIE ED 50 (df)
# 83 <-- 000083 (gdf)
#
# 258 colonie ed 51 <-- 0258 COLONIE ED 51 (df)
# 84 <-- 000084 (gdf)
#
# 259 colonie ed 52 <-- 0259 COLONIE ED 52 (df)
# 85 <-- 000085 (gdf)
#
# 26 albany w3 ed6 <-- 0026 ALBANY W3 ED6 (df)
# 86 <-- 000086 (gdf)
#
# 260 colonie ed 53 <-- 0260 COLONIE ED 53 (df)
# 87 <-- 000087 (gdf)
#
# 261 colonie ed 54 <-- 0261 COLONIE ED 54 (df)
# 88 <-- 000088 (gdf)
#
# 262 colonie ed 55 <-- 0262 COLONIE ED 55 (df)
# 89 <-- 000089 (gdf)
#
# 263 colonie ed 56 <-- 0263 COLONIE ED 56 (df)
# 9 <-- 000009 (gdf)
#
# 264 colonie ed 57 <-- 0264 COLONIE ED 57 (df)
# 90 <-- 000090 (gdf)
#
# 265 colonie ed 58 <-- 0265 COLONIE ED 58 (df)
# 91 <-- 000091 (gdf)
#
# 266 colonie ed 59 <-- 0266 COLONIE ED 59 (df)
# 92 <-- 000092 (gdf)
#
# 267 colonie ed 60 <-- 0267 COLONIE ED 60 (df)
# 93 <-- 000093 (gdf)
#
# 268 colonie ed 61 <-- 0268 COLONIE ED 61 (df)
# 94 <-- 000094 (gdf)
#
# 269 green island ed 1 <-- 0269 GREEN ISLAND ED 1 (df)
# 95 <-- 000095 (gdf)
#
# 27 albany w3 ed7 <-- 0027 ALBANY W3 ED7 (df)
# 96 <-- 000096 (gdf)
#
# 270 green island ed 2 <-- 0270 GREEN ISLAND ED 2 (df)
# 97 <-- 000097 (gdf)
#
# 271 green island ed 3 <-- 0271 GREEN ISLAND ED 3 (df)
# 98 <-- 000098 (gdf)
#
# 272 green island ed 4 <-- 0272 GREEN ISLAND ED 4 (df)
# 99 <-- 000099 (gdf)
#
# 274 guilderland ed 2 <-- 0274 GUILDERLAND ED 2 (df)
# voting district 107 <-- Voting District 000107 (gdf)
#
# 275 guilderland ed 3 <-- 0275 GUILDERLAND ED 3 (df)
# voting district 108 <-- Voting District 000108 (gdf)
#
# 276 guilderland ed 4 <-- 0276 GUILDERLAND ED 4 (df)
# voting district 109 <-- Voting District 000109 (gdf)
#
# 277 guilderland ed 5 <-- 0277 GUILDERLAND ED 5 (df)
# voting district 112 <-- Voting District 000112 (gdf)
#
# 278 guilderland ed 6 <-- 0278 GUILDERLAND ED 6 (df)
# voting district 114 <-- Voting District 000114 (gdf)
#
# 279 guilderland ed 7 <-- 0279 GUILDERLAND ED 7 (df)
# voting district 117 <-- Voting District 000117 (gdf)
#
# 28 albany w3 ed8 <-- 0028 ALBANY W3 ED8 (df)
# voting district 118 <-- Voting District 000118 (gdf)
#
# 280 guilderland ed 8 <-- 0280 GUILDERLAND ED 8 (df)
# voting district 119 <-- Voting District 000119 (gdf)
#
# 281 guilderland ed 9 <-- 0281 GUILDERLAND ED 9 (df)
# voting district 122 <-- Voting District 000122 (gdf)
#
# 282 guilderland ed 10 <-- 0282 GUILDERLAND ED 10 (df)
# voting district 127 <-- Voting District 000127 (gdf)
#
# 283 guilderland ed 11 <-- 0283 GUILDERLAND ED 11 (df)
# voting district 129 <-- Voting District 000129 (gdf)
#
# 284 guilderland ed 12 <-- 0284 GUILDERLAND ED 12 (df)
# voting district 132 <-- Voting District 000132 (gdf)
#
# 285 guilderland ed 13 <-- 0285 GUILDERLAND ED 13 (df)
# voting district 135 <-- Voting District 000135 (gdf)
#
# 286 guilderland ed 14 <-- 0286 GUILDERLAND ED 14 (df)
# voting district 136 <-- Voting District 000136 (gdf)
#
# 287 guilderland ed 15 <-- 0287 GUILDERLAND ED 15 (df)
# voting district 140 <-- Voting District 000140 (gdf)
#
# 288 guilderland ed 16 <-- 0288 GUILDERLAND ED 16 (df)
# voting district 141 <-- Voting District 000141 (gdf)
#
# 289 guilderland ed 17 <-- 0289 GUILDERLAND ED 17 (df)
# voting district 143 <-- Voting District 000143 (gdf)
#
# 29 albany w3 ed9 <-- 0029 ALBANY W3 ED9 (df)
# voting district 145 <-- Voting District 000145 (gdf)
#
# 290 guilderland ed 18 <-- 0290 GUILDERLAND ED 18 (df)
# voting district 146 <-- Voting District 000146 (gdf)
#
# 291 guilderland ed 19 <-- 0291 GUILDERLAND ED 19 (df)
# voting district 148 <-- Voting District 000148 (gdf)
#
# 292 guilderland ed 20 <-- 0292 GUILDERLAND ED 20 (df)
# voting district 150 <-- Voting District 000150 (gdf)
#
# 293 guilderland ed 21 <-- 0293 GUILDERLAND ED 21 (df)
# voting district 152 <-- Voting District 000152 (gdf)
#
# 294 guilderland ed 22 <-- 0294 GUILDERLAND ED 22 (df)
# voting district 154 <-- Voting District 000154 (gdf)
#
# 295 guilderland ed 23 <-- 0295 GUILDERLAND ED 23 (df)
# voting district 159 <-- Voting District 000159 (gdf)
#
# 296 guilderland ed 24 <-- 0296 GUILDERLAND ED 24 (df)
# voting district 160 <-- Voting District 000160 (gdf)
#
# 297 guilderland ed 25 <-- 0297 GUILDERLAND ED 25 (df)
# voting district 162 <-- Voting District 000162 (gdf)
#
# 298 guilderland ed 26 <-- 0298 GUILDERLAND ED 26 (df)
# voting district 163 <-- Voting District 000163 (gdf)
#
# 299 guilderland ed 27 <-- 0299 GUILDERLAND ED 27 (df)
# voting district 165 <-- Voting District 000165 (gdf)
#
# 3 albany w1 ed3 <-- 0003 ALBANY W1 ED3 (df)
# voting district 166 <-- Voting District 000166 (gdf)
#
# 30 albany w3 ed10 <-- 0030 ALBANY W3 ED10 (df)
# voting district 167 <-- Voting District 000167 (gdf)
#
# 300 guilderland ed 28 <-- 0300 GUILDERLAND ED 28 (df)
# voting district 168 <-- Voting District 000168 (gdf)
#
# 301 guilderland ed 29 <-- 0301 GUILDERLAND ED 29 (df)
# voting district 169 <-- Voting District 000169 (gdf)
#
# 302 guilderland ed 30 <-- 0302 GUILDERLAND ED 30 (df)
# voting district 172 <-- Voting District 000172 (gdf)
#
# 303 knox ed 1 <-- 0303 KNOX ED 1 (df)
# voting district 174 <-- Voting District 000174 (gdf)
#
# 304 knox ed 2 <-- 0304 KNOX ED 2 (df)
# voting district 175 <-- Voting District 000175 (gdf)
#
# 305 knox ed 3 <-- 0305 KNOX ED 3 (df)
# voting district 180 <-- Voting District 000180 (gdf)
#
# 306 new scotland ed 1 <-- 0306 NEW SCOTLAND ED 1 (df)
# voting district 182 <-- Voting District 000182 (gdf)
#
# 307 new scotland ed 2 <-- 0307 NEW SCOTLAND ED 2 (df)
# voting district 183 <-- Voting District 000183 (gdf)
#
# 308 new scotland ed 3 <-- 0308 NEW SCOTLAND ED 3 (df)
# voting district 185 <-- Voting District 000185 (gdf)
#
# 309 new scotland ed 4 <-- 0309 NEW SCOTLAND ED 4 (df)
# voting district 186 <-- Voting District 000186 (gdf)
#
# 31 albany w4 ed1 <-- 0031 ALBANY W4 ED1 (df)
# voting district 187 <-- Voting District 000187 (gdf)
#
# 310 new scotland ed 5 <-- 0310 NEW SCOTLAND ED 5 (df)
# voting district 191 <-- Voting District 000191 (gdf)
#
# 311 new scotland ed 6 <-- 0311 NEW SCOTLAND ED 6 (df)
# voting district 193 <-- Voting District 000193 (gdf)
#
# 312 new scotland ed 7 <-- 0312 NEW SCOTLAND ED 7 (df)
# voting district 194 <-- Voting District 000194 (gdf)
#
# 313 new scotland ed 8 <-- 0313 NEW SCOTLAND ED 8 (df)
# voting district 197 <-- Voting District 000197 (gdf)
#
# 314 rensselaerville ed 1 <-- 0314 RENSSELAERVILLE ED 1 (df)
# voting district 198 <-- Voting District 000198 (gdf)
#
# 315 rensselaerville ed 2 <-- 0315 RENSSELAERVILLE ED 2 (df)
# voting district 200 <-- Voting District 000200 (gdf)
#
# 316 rensselaerville ed 3 <-- 0316 RENSSELAERVILLE ED 3 (df)
# voting district 201 <-- Voting District 000201 (gdf)
#
# 317 westerlo ed 1 <-- 0317 WESTERLO ED 1 (df)
# voting district 206 <-- Voting District 000206 (gdf)
#
# 318 westerlo ed 2 <-- 0318 WESTERLO ED 2 (df)
# voting district 207 <-- Voting District 000207 (gdf)
#
# 319 westerlo ed 3 <-- 0319 WESTERLO ED 3 (df)
# voting district 210 <-- Voting District 000210 (gdf)
#
# 32 albany w4 ed2 <-- 0032 ALBANY W4 ED2 (df)
# voting district 214 <-- Voting District 000214 (gdf)
#
# 33 albany w4 ed3 <-- 0033 ALBANY W4 ED3 (df)
# voting district 215 <-- Voting District 000215 (gdf)
#
# 34 albany w4 ed4 <-- 0034 ALBANY W4 ED4 (df)
# voting district 217 <-- Voting District 000217 (gdf)
#
# 35 albany w4 ed5 <-- 0035 ALBANY W4 ED5 (df)
# voting district 218 <-- Voting District 000218 (gdf)
#
# 36 albany w4 ed6 <-- 0036 ALBANY W4 ED6 (df)
# voting district 222 <-- Voting District 000222 (gdf)
#
# 37 albany w5 ed1 <-- 0037 ALBANY W5 ED1 (df)
# voting district 223 <-- Voting District 000223 (gdf)
#
# 38 albany w5 ed2 <-- 0038 ALBANY W5 ED2 (df)
# voting district 225 <-- Voting District 000225 (gdf)
#
# 39 albany w5 ed3 <-- 0039 ALBANY W5 ED3 (df)
# voting district 226 <-- Voting District 000226 (gdf)
#
# 4 albany w1 ed4 <-- 0004 ALBANY W1 ED4 (df)
# voting district 229 <-- Voting District 000229 (gdf)
#
# 40 albany w5 ed4 <-- 0040 ALBANY W5 ED4 (df)
# voting district 230 <-- Voting District 000230 (gdf)
#
# 41 albany w5 ed5 <-- 0041 ALBANY W5 ED5 (df)
# voting district 234 <-- Voting District 000234 (gdf)
#
# 42 albany w5 ed6 <-- 0042 ALBANY W5 ED6 (df)
# voting district 235 <-- Voting District 000235 (gdf)
#
# 43 albany w5 ed7 <-- 0043 ALBANY W5 ED7 (df)
# voting district 239 <-- Voting District 000239 (gdf)
#
# 44 albany w6 ed1 <-- 0044 ALBANY W6 ED1 (df)
# voting district 240 <-- Voting District 000240 (gdf)
#
# 45 albany w6 ed2 <-- 0045 ALBANY W6 ED2 (df)
# voting district 243 <-- Voting District 000243 (gdf)
#
# 46 albany w6 ed3 <-- 0046 ALBANY W6 ED3 (df)
# voting district 244 <-- Voting District 000244 (gdf)
#
# 47 albany w6 ed4 <-- 0047 ALBANY W6 ED4 (df)
# voting district 245 <-- Voting District 000245 (gdf)
#
# 48 albany w6 ed5 <-- 0048 ALBANY W6 ED5 (df)
# voting district 249 <-- Voting District 000249 (gdf)
#
# 49 albany w6 ed6 <-- 0049 ALBANY W6 ED6 (df)
# voting district 250 <-- Voting District 000250 (gdf)
#
# 5 albany w1 ed5 <-- 0005 ALBANY W1 ED5 (df)
# voting district 255 <-- Voting District 000255 (gdf)
#
# 50 albany w6 ed7 <-- 0050 ALBANY W6 ED7 (df)
# voting district 256 <-- Voting District 000256 (gdf)
#
# 51 albany w6 ed8 <-- 0051 ALBANY W6 ED8 (df)
# voting district 257 <-- Voting District 000257 (gdf)
#
# 52 albany w7 ed1 <-- 0052 ALBANY W7 ED1 (df)
# voting district 260 <-- Voting District 000260 (gdf)
#
# 53 albany w7 ed2 <-- 0053 ALBANY W7 ED2 (df)
# voting district 262 <-- Voting District 000262 (gdf)
#
# 54 albany w7 ed3 <-- 0054 ALBANY W7 ED3 (df)
# voting district 263 <-- Voting District 000263 (gdf)
#
# 55 albany w7 ed4 <-- 0055 ALBANY W7 ED4 (df)
# voting district 267 <-- Voting District 000267 (gdf)
#
# 56 albany w7 ed5 <-- 0056 ALBANY W7 ED5 (df)
# voting district 268 <-- Voting District 000268 (gdf)
#
# 57 albany w7 ed6 <-- 0057 ALBANY W7 ED6 (df)
# voting district 269 <-- Voting District 000269 (gdf)
#
# 58 albany w7 ed7 <-- 0058 ALBANY W7 ED7 (df)
# voting district 270 <-- Voting District 000270 (gdf)
#
# 59 albany w7 ed8 <-- 0059 ALBANY W7 ED8 (df)
# voting district 272 <-- Voting District 000272 (gdf)
#
# 6 albany w1 ed6 <-- 0006 ALBANY W1 ED6 (df)
# voting district 273 <-- Voting District 000273 (gdf)
#
# 60 albany w8 ed1 <-- 0060 ALBANY W8 ED1 (df)
# voting district 276 <-- Voting District 000276 (gdf)
#
# 61 albany w8 ed2 <-- 0061 ALBANY W8 ED2 (df)
# voting district 277 <-- Voting District 000277 (gdf)
#
# 62 albany w8 ed3 <-- 0062 ALBANY W8 ED3 (df)
# voting district 280 <-- Voting District 000280 (gdf)
#
# 63 albany w8 ed4 <-- 0063 ALBANY W8 ED4 (df)
# voting district 282 <-- Voting District 000282 (gdf)
#
# 64 albany w8 ed5 <-- 0064 ALBANY W8 ED5 (df)
# voting district 283 <-- Voting District 000283 (gdf)
#
# 65 albany w8 ed6 <-- 0065 ALBANY W8 ED6 (df)
# voting district 285 <-- Voting District 000285 (gdf)
#
# 66 albany w8 ed7 <-- 0066 ALBANY W8 ED7 (df)
# voting district 286 <-- Voting District 000286 (gdf)
#
# 67 albany w8 ed8 <-- 0067 ALBANY W8 ED8 (df)
# voting district 287 <-- Voting District 000287 (gdf)
#
# 68 albany w8 ed9 <-- 0068 ALBANY W8 ED9 (df)
# voting district 290 <-- Voting District 000290 (gdf)
#
# 69 albany w9 ed1 <-- 0069 ALBANY W9 ED1 (df)
# voting district 292 <-- Voting District 000292 (gdf)
#
# 7 albany w1 ed7 <-- 0007 ALBANY W1 ED7 (df)
# voting district 295 <-- Voting District 000295 (gdf)
#
# 70 albany w9 ed2 <-- 0070 ALBANY W9 ED2 (df)
# voting district 296 <-- Voting District 000296 (gdf)
#
# 71 albany w9 ed3 <-- 0071 ALBANY W9 ED3 (df)
# voting district 297 <-- Voting District 000297 (gdf)
#
# 72 albany w9 ed4 <-- 0072 ALBANY W9 ED4 (df)
# voting district 299 <-- Voting District 000299 (gdf)
#
# 73 albany w9 ed5 <-- 0073 ALBANY W9 ED5 (df)
# voting district 300 <-- Voting District 000300 (gdf)
#
# 74 albany w9 ed6 <-- 0074 ALBANY W9 ED6 (df)
# voting district 301 <-- Voting District 000301 (gdf)
#
# 75 albany w9 ed7 <-- 0075 ALBANY W9 ED7 (df)
# voting district 304 <-- Voting District 000304 (gdf)
#
# 76 albany w9 ed8 <-- 0076 ALBANY W9 ED8 (df)
# voting district 307 <-- Voting District 000307 (gdf)
#
# 77 albany w9 ed9 <-- 0077 ALBANY W9 ED9 (df)
# voting district 308 <-- Voting District 000308 (gdf)
#
# 78 albany w10 ed1 <-- 0078 ALBANY W10 ED1 (df)
# voting district 309 <-- Voting District 000309 (gdf)
#
# 79 albany w10 ed2 <-- 0079 ALBANY W10 ED2 (df)
# voting district 312 <-- Voting District 000312 (gdf)
#
# 8 albany w1 ed8 <-- 0008 ALBANY W1 ED8 (df)
# voting district 313 <-- Voting District 000313 (gdf)
#
# 80 albany w10 ed3 <-- 0080 ALBANY W10 ED3 (df)
# voting district 315 <-- Voting District 000315 (gdf)
#
# 81 albany w10 ed4 <-- 0081 ALBANY W10 ED4 (df)
# voting district 316 <-- Voting District 000316 (gdf)
#
# 82 albany w10 ed5 <-- 0082 ALBANY W10 ED5 (df)
# voting district 318 <-- Voting District 000318 (gdf)
#
# 83 albany w10 ed6 <-- 0083 ALBANY W10 ED6 (df)
# voting district 319 <-- Voting District 000319 (gdf)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-ffbe7273ddb3> in <module>
#      79             print("\nLook for parterns and use change the parameters to edit_precinct_name accordingly.\n")
#      80             for index, (original_precinct_name_df, edited_precinct_name_df) in enumerate(precinct_list_df):
# ---> 81                 original_precinct_name_gdf, edited_precinct_name_gdf = precinct_list_gdf[index]
#      82                 if edited_precinct_name_df in unmatched_precincts_df and edited_precinct_name_gdf in unmatched_precincts_gdf:
#      83                     print("{} <-- {} ({})".format(edited_precinct_name_df, original_precinct_name_df, dataset_name_df))
#
# IndexError: list index out of range
